# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import seaborn as sn
import matplotlib.pyplot as plt
sn.set(style="white", color_codes=True)

# %%
wcup = pd.read_csv('C:/Users/Mert/Downloads/world_cup_2022.csv', encoding='latin-1')

# %%
wcup.head()
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
wcup.columns = wcup.columns.str.replace(' ', '')

# %%
wcup.head(3)
# Out:
#    RoundID  MatchID TeamInitials            CoachName Line-up  ShirtNumber  \
# 0      201     1096          FRA  CAUDRON Raoul (FRA)       S            0
# 1      201     1096          MEX     LUQUE Juan (MEX)       S            0
# 2      201     1096          FRA  CAUDRON Raoul (FRA)       S            0
#
#          PlayerName Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'

# %%
wcup["MatchID"].value_counts()
# Out:
# 300186497    92
# 300186501    92
# 300186487    92
# 300186491    92
# 300186460    92
#              ..
# 1094         35
# 1092         34
# 1096         33
# 1141         33
# 1090         32
# Name: MatchID, Length: 836, dtype: int64

# %%
wcup["PlayerName"].value_counts()
# Out:
# RONALDO            33
# KLOSE              32
# OSCAR              28
# Mï¿½LLER           28
# JULIO CESAR        26
#                    ..
# PEDROSA             1
# TINOCO              1
# SYLVIO HOFFMANN     1
# ARMANDINHO          1
# Alberto GALATEO     1
# Name: PlayerName, Length: 7663, dtype: int64

# %%
wcup.dropna
# Out:
# <bound method DataFrame.dropna of        RoundID    MatchID TeamInitials                CoachName Line-up  \
# 0          201       1096          FRA      CAUDRON Raoul (FRA)       S
# 1          201       1096          MEX         LUQUE Juan (MEX)       S
# 2          201       1096          FRA      CAUDRON Raoul (FRA)       S
# 3          201       1096          MEX         LUQUE Juan (MEX)       S
# 4          201       1096          FRA      CAUDRON Raoul (FRA)       S
# ...        ...        ...          ...                      ...     ...
# 37779   255959  300186501          ARG  SABELLA Alejandro (ARG)       N
# 37780   255959  300186501          GER       LOEW Joachim (GER)       N
# 37781   255959  300186501          ARG  SABELLA Alejandro (ARG)       N
# 37782   255959  300186501          GER       LOEW Joachim (GER)       N
# 37783   255959  300186501          ARG  SABELLA Alejandro (ARG)       N
#
#        ShirtNumber        PlayerName Position       Event
# ...

# %%
wcup["PlayerName"].value_counts()
# Out:
# RONALDO            33
# KLOSE              32
# OSCAR              28
# Mï¿½LLER           28
# JULIO CESAR        26
#                    ..
# PEDROSA             1
# TINOCO              1
# SYLVIO HOFFMANN     1
# ARMANDINHO          1
# Alberto GALATEO     1
# Name: PlayerName, Length: 7663, dtype: int64

# %%
wcup=wcup.dropna(axis=1,how='all')

# %%
wcup.head(5)
# Out:
#    RoundID  MatchID TeamInitials            CoachName Line-up  ShirtNumber  \
# 0      201     1096          FRA  CAUDRON Raoul (FRA)       S            0
# 1      201     1096          MEX     LUQUE Juan (MEX)       S            0
# 2      201     1096          FRA  CAUDRON Raoul (FRA)       S            0
# 3      201     1096          MEX     LUQUE Juan (MEX)       S            0
# 4      201     1096          FRA  CAUDRON Raoul (FRA)       S            0
#
#          PlayerName Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
wcup["TeamInitials"].value_counts()
# Out:
# BRA    2403
# ITA    1843
# ARG    1807
# ENG    1378
# FRG    1364
#        ...
# KUW      66
# CAN      66
# UAE      66
# CUB      45
# INH      18
# Name: TeamInitials, Length: 82, dtype: int64

# %%
wcup_2 = wcup[['TeamInitials','Position','Event']].copy()

# %%
wcup_2.head(5)
# Out:
#   TeamInitials Position Event
# 0          FRA       GK   NaN
# 1          MEX       GK   NaN
# 2          FRA      NaN  G40'
# 3          MEX      NaN  G70'
# 4          FRA      NaN   NaN

# %%
wcup["Position"].value_counts()
# Out:
# GK     2441
# C      1510
# GKC     192
# Name: Position, dtype: int64

# %%
sn.jointplot(x="Event", y="TeamInitials", data=wcup_2, size=5)

# %%
print (wcup_2[pd.to_numeric(wcup_2.TeamInitials, errors='coerce').isnull()])
# Out:
#       TeamInitials Position       Event
# 0              FRA       GK         NaN
# 1              MEX       GK         NaN
# 2              FRA      NaN        G40'
# 3              MEX      NaN        G70'
# 4              FRA      NaN         NaN
# ...            ...      ...         ...
# 37779          ARG      NaN         NaN
# 37780          GER      NaN         NaN
# 37781          ARG      NaN  IH46' Y65'
# 37782          GER      NaN         NaN
# 37783          ARG      NaN         NaN
#
# [37784 rows x 3 columns]

# %%
sn.FacetGrid(wcup_2, hue ="Position", size =5)

# %%
wcup_2.dropna()
# Out:
#       TeamInitials Position      Event
# 35             USA        C       G45'
# 74             BRA        C       G62'
# 113            PER        C       R70'
# 415            BRA        C  G67' G83'
# 468            PAR        C       G40'
# ...            ...      ...        ...
# 37658          NED        C       O96'
# 37693          NED       GK       O90'
# 37694          BRA        C        Y2'
# 37705          NED        C        P3'
# 37715          NED       GK       I90'
#
# [573 rows x 3 columns]

# %%
wcup_2['Position'].value_counts()
# Out:
# GK     2441
# C      1510
# GKC     192
# Name: Position, dtype: int64

# %%
wcup_2 = wcup_2[~wcup_2['Event'].isnull()]

# %%
wcup_2 = wcup_2[~wcup_2['Position'].isnull()]

# %%
wcup_2 = wcup_2[~wcup_2['TeamInitials'].isnull()]

# %%
wcup_2 = wcup_2[wcup_2['Event'].str.isnumeric()]

# %%
wcup_2 = wcup_2[wcup_2['Position'].str.isnumeric()]

# %%
wcup_2 = wcup_2[wcup_2['TeamInitials'].str.isnumeric()]

# %%
wcup_2[['Event']] = wcup_2[['Event']].astype(int)

# %%
wcup_2[['Position']] = wcup_2[['Position']].astype(int)

# %%
wcup_2[['TeamInitials']] = wcup_2[['TeamInitials']].astype(int)

# %%
sn.FacetGrid(wcup_2, hue="Position", size=6) \
   .map(sn.kdeplot, "TeamInitials") \
   .add_legend()

# %%
sn.pairplot(wcup_2.drop("TeamInitials", axis=1), hue="Position", size=3)

# %%
sn.pairplot(wcup_2.drop("Position", axis=1), hue="Event", size=3, diag_kind="kde")
